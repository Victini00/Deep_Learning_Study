# %% [markdown]
# #### More layer...
#
#
# * Less number of params.
#
#     Ex)
#
#
#     5x5 CNN kernel : 25 params
#
#
#     3x3 CNN kernel -> 3x3 CNN kernel : 2 * 9 = 18 params!
#
#
# * More activation function: more expressive.
#
# * Efficiency of learning: we can simplify the problem that each layer should solve.
#
#
#     but less layer: each layer should solve lots of problem.

# %% [markdown]
# #### History of Deep Learning ~ ImageNet
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### VGG
#
# Easy to utilize. simple structure
#
#
# ##### GoogLeNet
#
# "Inception Structure"
#
# ![image.png](attachment:image.png)
#
#
# ##### ResNet
#
# "Skip Connection"

# %% [markdown]
# ## Calculation speed in Deep learning
#
# CNN calculation time is important.
#
# * Use GPU.
#
#     CUDA, cuDNN
#
# * Scale out
#
#     tensorflow, CNTK
#
# * Numerical Precision
#
#     not so important.. half-precision(16-bit)
